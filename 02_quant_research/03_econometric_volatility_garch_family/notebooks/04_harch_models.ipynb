# %% [markdown]
# # 04 harch models
#
# This notebook contains detailed analysis for this component.
# Run main.py for the complete pipeline.

# %%
import sys
sys.path.append('..')
# Import relevant modules and run analysis
